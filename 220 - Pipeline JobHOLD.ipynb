# %%
from azureml.core import Workspace
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# Access the Workspace
ws = Workspace.from_config("./config")

# %%
# Create custom environment
from azureml.core import Environment
from azureml.core.environment import CondaDependencies

myenv = Environment(name="MyEnvironmentAuto")
myenv_dep = CondaDependencies.create(conda_packages=['scikit-learn', 'pandas'])
myenv.python.conda_dependencies = myenv_dep
myenv.register(ws)
# Out:
# {
#     "assetId": "azureml://locations/westus/workspaces/54b058d1-e724-4986-aece-5eb3256cb2e6/environments/MyEnvironmentAuto/versions/2",
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20240304.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "buildContext": null,
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "MyEnvironmentAuto",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.8.13",
#                 {
#                     "pip": [
#                         "azureml-defaults"
#                     ]
#                 },
#                 "scikit-learn",
#                 "pandas"
#             ],
#             "name": "project_environment"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "2"
# }

# %%
# Create a compute cluster for pipeline

cluster_name = "pipeline-cluster"

from azureml.core.compute import AmlCompute, ComputeTarget
compute_config = AmlCompute.provisioning_configuration(
    vm_size="STANDARD_D11_V2",
    max_nodes=2
)

compute_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
compute_cluster.wait_for_completion()
# Out:
# Provisioning operation finished, operation "Succeeded"

# %%
# Define Pipeline steps

# Create Run Configurations for the steps
from azureml.core.runconfig import RunConfiguration
run_config = RunConfiguration()
run_config.target = compute_cluster
run_config.environment = myenv

# Define inputs and outputs
from azureml.pipeline.steps import PythonScriptStep
from azureml.pipeline.core import PipelineData
input_ds = ws.datasets.get("Defaults")
dataFolder = PipelineData("datafolder", datastore=ws.get_default_datastore())


# Step 01 - Data Preparation
dataPrep_step = PythonScriptStep(name="01 Data Preparation",
                                 source_directory=".",
                                 script_name="220 - Dataprep Pipeline.py",
                                 inputs=[input_ds.as_named_input("raw_data")],
                                 outputs=[dataFolder],
                                 runconfig=run_config,
                                 arguments=["--datafolder", dataFolder])

# Step 02 - Train the model
train_step = PythonScriptStep(name="02 Train the Model",
                                 source_directory=".",
                                 script_name="220 - Training Pipeline.py",
                                 inputs=[dataFolder],
                                 runconfig=run_config,
                                 arguments=["--datafolder", dataFolder])

# Configure and build the pipeline
from azureml.pipeline.core import Pipeline
steps = [dataPrep_step, train_step]
new_pipeline = Pipeline(workspace=ws, steps=steps)


# Create the experiment and run the pipeline
from azureml.core import Experiment

new_experiment = Experiment(workspace=ws, name="PipelineExp01")
new_pipeline_run = new_experiment.submit(new_pipeline)
new_pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step 01 Data Preparation [b7f8994f][afa1209e-7c29-41fb-8ff5-bbd27e8036d6], (This step will run and generate new outputs)
# Created step 02 Train the Model [556c447f][bec7298e-ca10-4989-b6f3-602f5771bc92], (This step will run and generate new outputs)
# Submitted PipelineRun 0935b6ed-10c5-42e3-936d-4eef8fa82e1f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/0935b6ed-10c5-42e3-936d-4eef8fa82e1f?wsid=/subscriptions/49e690c2-0fc4-42a6-ba64-9ea0fa04ddda/resourcegroups/AzureMLsdkgroup/workspaces/slavasdkworkspace&tid=77487836-da45-4554-ad65-1775dca67ca5
# PipelineRunId: 0935b6ed-10c5-42e3-936d-4eef8fa82e1f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/0935b6ed-10c5-42e3-936d-4eef8fa82e1f?wsid=/subscriptions/49e690c2-0fc4-42a6-ba64-9ea0fa04ddda/resourcegroups/AzureMLsdkgroup/workspaces/slavasdkworkspace&tid=77487836-da45-4554-ad65-1775dca67ca5
# PipelineRun Status: Running
#
#
# StepRunId: 99dcc163-3488-4096-9d34-b6501fb0e94d
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/99dcc163-3488-4096-9d34-b6501fb0e94d?wsid=/subscriptions/49e690c2-0fc4-42a6-ba64-9ea0fa04ddda/resourcegroups/AzureMLsdkgroup/workspaces/slavasdkworkspace&tid=77487836-da45-4554-ad65-1775dca67ca5
# StepRun( 01 Data Preparation ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# StepRun( 01 Data Preparation ) Status: Running
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\msrest\serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\pipeline\core\run.py:742, in StepRun.wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     741 try:
# --> 742     return self._stream_run_output(timeout_seconds=timeout_seconds,
#     743                                    raise_on_error=raise_on_error)
#     744 except KeyboardInterrupt:
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\pipeline\core\run.py:804, in StepRun._stream_run_output(self, timeout_seconds, raise_on_error)
#     803 try:
# --> 804     content = download_file_stream(current_log_uri, session=session)
#     805     num_printed_lines = incremental_print(content, num_printed_lines)
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_file_utils\file_utils.py:316, in download_file_stream(source_uri, encoding, download_to_bytes, max_retries, stream, protocol, session, _validate_check_sum, max_concurrency)
#     314         return blob.readall()
# --> 316     return _retry(exec_func, max_retries=max_retries)
#     318 # download using requests.Session
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_file_utils\file_utils.py:468, in _retry(exec_func, clean_up_func, max_retries, retry_on_exceptions, fail_on_exceptions)
#     467 try:
# --> 468     return exec_func()
#     469 except fail_on_exceptions as ex:
#     470     # if condition to fail on different exceptions differently
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_file_utils\file_utils.py:306, in download_file_stream.<locals>.exec_func()
#     305 else:
# --> 306     blob = blob_service.get_blob_client(
#     307         container=container_name,
#     308         blob=blob_name
#     309     ).download_blob(
#     310         max_concurrency=max_concurrency,
#     311         validate_content=_validate_check_sum,
#     312         encoding=encoding
#     313     )
#     314 return blob.readall()
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\tracing\decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_vendor\azure_storage\blob\_blob_client.py:871, in BlobClient.download_blob(self, offset, length, **kwargs)
#     867 options = self._download_blob_options(
#     868     offset=offset,
#     869     length=length,
#     870     **kwargs)
# --> 871 return StorageStreamDownloader(**options)
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_vendor\azure_storage\blob\_download.py:359, in StorageStreamDownloader.__init__(self, clients, config, start_range, end_range, validate_content, encryption_options, max_concurrency, name, container, encoding, **kwargs)
#     351 self._initial_range, self._initial_offset = process_range_and_offset(
#     352     initial_request_start,
#     353     initial_request_end,
#    (...)
#     356     self._encryption_data
#     357 )
# --> 359 self._response = self._initial_request()
#     360 self.properties = self._response.properties
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_vendor\azure_storage\blob\_download.py:411, in StorageStreamDownloader._initial_request(self)
#     410 try:
# --> 411     location_mode, response = self._clients.blob.download(
#     412         range=range_header,
#     413         range_get_content_md5=range_validation,
#     414         validate_content=self._validate_content,
#     415         data_stream_total=None,
#     416         download_stream_current=0,
#     417         **self._request_options
#     418     )
#     420     # Check the location we read from to ensure we use the same one
#     421     # for subsequent requests.
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\tracing\decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_vendor\azure_storage\blob\_generated\operations\_blob_operations.py:1700, in BlobOperations.download(self, snapshot, version_id, timeout, range, range_get_content_md5, range_get_content_crc64, request_id_parameter, lease_access_conditions, cpk_info, modified_access_conditions, **kwargs)
#    1698 request.url = self._client.format_url(request.url)  # type: ignore
# -> 1700 pipeline_response = self._client._pipeline.run(  # type: ignore # pylint: disable=protected-access
#    1701     request,
#    1702     stream=True,
#    1703     **kwargs
#    1704 )
#    1705 response = pipeline_response.http_response
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:230, in Pipeline.run(self, request, **kwargs)
#     229 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 230 return first_node.send(pipeline_request)
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 86 (2 times)]
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\policies\_redirect.py:197, in RedirectPolicy.send(self, request)
#     196 while retryable:
# --> 197     response = self.next.send(request)
#     198     redirect_location = self.get_redirect_location(response)
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_vendor\azure_storage\blob\_shared\policies.py:518, in StorageRetryPolicy.send(self, request)
#     517 try:
# --> 518     response = self.next.send(request)
#     519     if is_retry(response, retry_settings['mode']):
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_vendor\azure_storage\blob\_shared\policies.py:313, in StorageResponseHook.send(self, request)
#     310 response_callback = request.context.get('response_callback') or \
#     311     request.context.options.pop('raw_response_hook', self._response_callback)
# --> 313 response = self.next.send(request)
#     315 will_retry = is_retry(response, request.context.options.get('mode'))
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\_base.py:119, in _TransportRunner.send(self, request)
#     116 cleanup_kwargs_for_transport(request.context.options)
#     117 return PipelineResponse(
#     118     request.http_request,
# --> 119     self._sender.send(request.http_request, **request.context.options),
#     120     context=request.context,
#     121 )
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\_vendor\azure_storage\blob\_shared\base_client.py:330, in TransportWrapper.send(self, request, **kwargs)
#     329 def send(self, request, **kwargs):
# --> 330     return self._transport.send(request, **kwargs)
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azure\core\pipeline\transport\_requests_basic.py:347, in RequestsTransport.send(self, request, proxies, **kwargs)
#     346     timeout = (connection_timeout, read_timeout)
# --> 347 response = self.session.request(  # type: ignore
#     348     request.method,
#     349     request.url,
#     350     headers=request.headers,
#     351     data=request.data,
#     352     files=request.files,
#     353     verify=kwargs.pop("connection_verify", self.connection_config.verify),
#     354     timeout=timeout,
#     355     cert=kwargs.pop("connection_cert", self.connection_config.cert),
#     356     allow_redirects=False,
#     357     proxies=proxies,
#     358     **kwargs
#     359 )
#     360 response.raw.enforce_content_length = True
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\urllib3\connection.py:616, in HTTPSConnection.connect(self)
#     615 sock: socket.socket | ssl.SSLSocket
# --> 616 self.sock = sock = self._new_conn()
#     617 server_hostname: str = self.host
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ExperimentExecutionException              Traceback (most recent call last)
# Cell In[8], line 44
#      42 new_experiment = Experiment(workspace=ws, name="PipelineExp01")
#      43 new_pipeline_run = new_experiment.submit(new_pipeline)
# ---> 44 new_pipeline_run.wait_for_completion(show_output=True)
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\pipeline\core\run.py:295, in PipelineRun.wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     293 print('\n')
#     294 try:
# --> 295     step_run.wait_for_completion(timeout_seconds=timeout_seconds - time_elapsed,
#     296                                  raise_on_error=raise_on_error)
#     297 except TypeError as e:
#     298     # If there are package conflicts in the user's environment, the run rehydration
#     299     # will not work and we will receive a Run object instead of StepRun.
#     300     # Run.wait_for_completion() does not have a parameter timeout_seconds, which
#     301     # will generate a TypeError here.  As a workaround, call the method without
#     302     # this parameter.
#     303     if not isinstance(step_run, StepRun):
#
# File c:\Users\User\anaconda3\envs\newtensorflow\lib\site-packages\azureml\pipeline\core\run.py:750, in StepRun.wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     744     except KeyboardInterrupt:
#     745         error_message = "The output streaming for the run interrupted.\n" \
#     746                         "But the run is still executing on the compute target. \n" \
#     747                         "Details for canceling the run can be found here: " \
#     748                         "https://aka.ms/aml-docs-cancel-run"
# --> 750         raise ExperimentExecutionException(error_message)
#     751 else:
#     752     status = self.get_status()
#
# ExperimentExecutionException: ExperimentExecutionException:
# 	Message: The output streaming for the run interrupted.
# But the run is still executing on the compute target.
# Details for canceling the run can be found here: https://aka.ms/aml-docs-cancel-run
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "The output streaming for the run interrupted.\nBut the run is still executing on the compute target. \nDetails for canceling the run can be found here: https://aka.ms/aml-docs-cancel-run"
#     }
# }
